# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import math
x1 = []
x2 = []
y1 = []
y2 = []
p = 5
for i in range(1, 100):
    x_ = i/100
    x1.append(x_)
    x2.append(x_*(-1))
    y1.append(1/x_)
    y2.append((-1)/x_)
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')
