# %%
#5. Найдите нормальное псевдорешение недоопределенной системы
# %matplotlib inline
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

import scipy
import scipy.linalg
import matplotlib.pyplot as plt

    
def Q(x, y, z):
    return(x**2 + y**2 + z**2)

fig = figure()
ax = Axes3D(fig)
y = np.arange(-5, 5)
z = np.arange(-5, 5)
y, z = np.meshgrid(y, z)
z = Q(1-2*y+z, y, z)
ax.plot_wireframe(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
show()

a = np.array([[1, 2, -1], [8, -5, 2]])
b = np.array([12, 1])
np.linalg.lstsq(a, b)
# Out:
# C:\Users\shpin\AppData\Local\Temp/ipykernel_5320/1270351929.py:16: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\shpin\AppData\Local\Temp/ipykernel_5320/1270351929.py:29: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   np.linalg.lstsq(a, b)
# (array([ 2.86346863,  3.63468635, -1.86715867]),
#  array([], dtype=float64),
#  2,
#  array([9.65316119, 2.41173777]))
